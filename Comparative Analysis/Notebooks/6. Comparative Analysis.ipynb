# %%
from formulas import *
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf

keras = tf.keras

# %% [markdown]
# # Summary of ALL Model Results

# %% [markdown]
# ### Bringing in values from other deep learning models

# %%
# CREATING A DICTIONARY TO STORE ALL OF OUR MODEL TRAINING SCORES TO VIEW LATER
model_mae_scores = {}
model_mae_scores['LINEAR REGRESSION'] = 18.245
model_mae_scores['ARIMA '] = 20.006
model_mae_scores['SMA 5'] = 45.33
model_mae_scores['SMA 20'] = 88.5
model_mae_scores['LSTM '] = 11.557
model_mae_scores['NAIVE BAYES'] = 13.175

# %%
# Store MAE scores
# %store model_mae_scores
# Out:
# Stored 'model_mae_scores' (dict)

# %%
# %store -r model_mae_scores
mae_series = pd.Series(model_mae_scores)
model_mae_scores
# Out:
# {'LINEAR REGRESSION': 18.245,
#  'ARIMA ': 20.006,
#  'SMA 5': 45.33,
#  'SMA 20': 88.5,
#  'LSTM ': 11.557,
#  'NAIVE BAYES': 13.175}

# %%
# Sort vales for clean bar chart
order = mae_series.sort_values()

# %%
order = mae_series.sort_values()

# Set the figure size to make the bar chart bigger
plt.figure(figsize=(10, 6))

# Increase the gap between bars by setting the width parameter
ax = sns.barplot(x=order.index, y=order.values, width=0.6)  # You can adjust the width as needed
plt.ylabel('Mean Absolute Error')
plt.title('Comparison of Six Models with Mean Average Error (MAE)')

# Annotate bars with their respective values
for index, value in enumerate(order.values):
    ax.text(index, value, str(value), ha='center', va='bottom', fontsize=12, color='black')

# Rotate x-axis labels to horizontal
plt.xticks(rotation=0)

plt.tight_layout()
plt.savefig('../Images/COMPARISION/MAE OF ALL MODELS TESTED_VERTICAL_WITH_HORIZONTAL_LABELS_AND_INCREASED_GAP')  # Save the plot
plt.show()
